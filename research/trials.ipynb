# %%
from langchain.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# %pwd
# Out:
# '/Users/sakib/Documents/Project/Chatbot'

# %%
# Extract text from PDF files
def load_pdf_files(data):
    loader = DirectoryLoader(
        data,
        glob="*.pdf",
        loader_cls=PyPDFLoader
    )

    documents = loader.load()
    return documents

# %%
extracted_data = load_pdf_files("data")

# %%
extracted_data
# Out:
# [Document(metadata={'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Travel Assistant Book', 'source': 'data/Travel Assistant Book.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='Toronto  —  Detailed  Overview  With  Tourist  Attractions   Toronto  is  the  largest  and  most  influential  city  in  Canada,  positioned  along  the  northwestern  \nshore\n \nof\n \nLake\n \nOntario\n \nand\n \nrecognized\n \nas\n \nthe\n \nnation’s\n \ncultural,\n \nfinancial,\n \nand\n \nentertainment\n \ncapital.\n \nCelebrated\n \nas\n \none\n \nof\n \nthe\n \nmost\n \nmulticultural\n \ncities\n \nin\n \nthe\n \nworld,\n \nToronto\n \nis\n \nhome\n \nto\n \nover\n \n200\n \nethnic\n \ncommunities,\n \ncreating\n \nan\n \nincredibly\n \ndiverse\n \natmosphere\n \nreflected\n \nin\n \nits\n \nneighborhoods,\n \nfood\n \nscene,\n \nfestivals,\n \nand\n \neveryday\n \nlife.\n \nThe\n \ncity’s\n \nmodern\n \nskyline—dominated\n \nby\n \nthe\n \niconic\n \n553-meter\n \nCN\n \nTower—sits\n \nabove\n \na\n \nbustling\n \nurban\n \ncore\n \nfilled\n \nwith\n \ntheatres,\n \nmuseums,\n \nshopping\n \ndistricts,\n \nand\n \nwaterfront\n \nattractions.\n \nToronto\n \nforms\n \nthe\n \nheart\n \nof\n \nthe\n \nGreater\n \nToronto\n \nArea\n \n(GTA),\n \nwhich\n \nincludes\n \nsurrounding\n \ncities\n \nsuch\n \nas\n \nMississauga,\n \nBrampton,\n \nMarkham,\n \nVaughan,\n \nRichmond\n \nHill,\n \nand\n \nPickering,\n \nmaking\n \nit\n \none\n \nof\n \nNorth\n \nAmerica’s\n \nlargest\n \nmetropolitan\n \nregions.\n \nThe\n \ngeography\n \nrevolves\n \naround\n \nToronto\n \nHarbour\n \nand\n \nan\n \nextensive\n \nwaterfront,\n \nwith\n \nvibrant\n \ndistricts\n \nbranching\n \noutward\n \ninto\n \nmulticultural\n \npockets\n \nand\n \nsuburban\n \ncommunities.\n \nToronto’s  continental  climate,  influenced  by  Lake  Ontario,  brings  cold  but  manageable  winters  \nranging\n \nfrom\n \n−5°C\n \nto\n \n−15°C,\n \nwarm\n \nand\n \nactive\n \nsummers\n \nbetween\n \n22°C\n \nand\n \n30°C,\n \nand\n \nmild\n \nbut\n \nwindy\n \nconditions\n \nin\n \nspring\n \nand\n \nfall—each\n \nseason\n \nshaping\n \nthe\n \ncity’s\n \ntourism\n \npatterns.\n \nThe\n \ncity\n \nattracts\n \nmillions\n \nof\n \nvisitors\n \nannually\n \nfor\n \nits\n \nblend\n \nof\n \nnatural\n \nbeauty,\n \ncultural\n \nrichness,\n \nand\n \nworld-class\n \nattractions.\n \nThe\n \nCN\n \nTower\n \nremains\n \nthe\n \nmost\n \nfamous\n \nlandmark,\n \noffering\n \nglass-floor\n \nviews,\n \na\n \nrevolving\n \nrestaurant,\n \nand\n \nthe\n \nthrilling\n \noutdoor\n \nEdgeWalk\n \nexperience.\n \nNature\n \nlovers\n \nenjoy\n \nthe\n \nToronto\n \nIslands,\n \nreached\n \nby\n \na\n \nshort\n \nferry\n \nride,\n \nwhere\n \nbeaches,\n \nbike\n \npaths,\n \npicnic\n \nspots,\n \nand\n \nskyline\n \nviews\n \ncreate\n \na\n \npeaceful\n \nescape\n \nfrom\n \ndowntown.\n \nHigh\n \nPark\n \nis\n \nanother\n \nmajor\n \noutdoor\n \nspace,\n \nwell-known\n \nfor\n \ncherry\n \nblossoms\n \nin\n \nspring,\n \nextensive\n \ntrails,\n \nand\n \nfamily-friendly\n \nactivities.\n \nFor\n \ndramatic\n \nlakefront\n \nscenery,\n \nthe\n \nScarborough\n \nBluffs\n \nprovide\n \ntowering\n \ncliffs,\n \npanoramic\n \nviews,\n \nand\n \npicturesque\n \nbeaches.\n \nCulturally,  Toronto  offers  exceptional  institutions  such  as  the  Royal  Ontario  Museum—Canada’s  \nlargest\n \nmuseum\n \nfeaturing\n \nglobal\n \nhistory,\n \ndinosaurs,\n \nand\n \nIndigenous\n \ncollections—and\n \nthe\n \nArt\n \nGallery\n \nof\n \nOntario,\n \nwhich\n \nhouses\n \nmore\n \nthan\n \n95,000\n \nworks\n \nand\n \noffers\n \nfree\n \nadmission\n \non\n \nWednesday\n \nevenings.\n \nShopping\n \ndistricts\n \nlike\n \nthe\n \nEaton\n \nCentre,\n \nYorkdale\n \nMall,\n \nQueen\n \nStreet\n \nWest,\n \nand\n \nKensington\n \nMarket\n \noffer\n \neverything\n \nfrom\n \nluxury\n \nbrands\n \nto\n \nvintage\n \nfinds\n \nand\n \nartisanal\n \n ...
#  Document(metadata={'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Travel Assistant Book', 'source': 'data/Travel Assistant Book.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='influences  blend  seamlessly  with  Canadian  identity,  offering  tourists  an  exciting  mix  of  \nattractions,\n \nnatural\n \nbeauty,\n \nand\n \ndiverse\n \nexperiences.\n \nIn  addition  to  its  cultural  and  scenic  appeal,  Toronto  offers  a  year-round  calendar  of  festivals  and  \nevents\n \nthat\n \ndraw\n \nvisitors\n \nfrom\n \naround\n \nthe\n \nworld.\n \nDuring\n \nthe\n \nsummer,\n \nthe\n \ncity\n \nbecomes\n \na\n \nhub\n \nof\n \ncelebration\n \nwith\n \nevents\n \nlike\n \nthe\n \nToronto\n \nInternational\n \nFilm\n \nFestival\n \n(TIFF),\n \nCaribbean\n \nCarnival,\n \nNuit\n \nBlanche,\n \nand\n \ncountless\n \nmulticultural\n \nstreet\n \nfestivals\n \nthat\n \nreflect\n \nthe\n \ncity’s\n \ndiversity.\n \nWinter\n \nbrings\n \nits\n \nown\n \ncharm\n \nwith\n \nChristmas\n \nmarkets,\n \noutdoor\n \nskating\n \nrinks,\n \nand\n \nilluminated\n \nurban\n \nspaces\n \nthat\n \ntransform\n \nthe\n \ncity\n \ninto\n \na\n \nvibrant\n \nwinter\n \nwonderland.\n \nToronto’s\n \nculinary\n \nscene\n \nis\n \nequally\n \nunmatched,\n \nranging\n \nfrom\n \nMichelin-star\n \nrestaurants\n \nand\n \nglobally\n \ninspired\n \nfine\n \ndining\n \nto\n \nauthentic\n \nneighborhood\n \neateries\n \nrepresenting\n \ncuisines\n \nfrom\n \nvirtually\n \nevery\n \nculture.\n \nThis\n \nfood\n \nlandscape\n \nreflects\n \nthe\n \ncity’s\n \nmulticultural\n \nidentity\n \nand\n \nensures\n \nthat\n \nvisitors\n \ncan\n \nenjoy\n \na\n \nworld\n \nof\n \nflavors\n \nwithin\n \na\n \nsingle\n \ntrip.\n \nBeyond  the  central  attractions,  Toronto  serves  as  a  gateway  to  some  of  Ontario’s  most  iconic  \ntourist\n \nexperiences.\n \nNiagara\n \nFalls,\n \none\n \nof\n \nthe\n \nworld’s\n \nmost\n \nfamous\n \nnatural\n \nwonders,\n \nis\n \nonly\n \na\n \n1.5-hour\n \ndrive\n \naway\n \nand\n \nis\n \na\n \npopular\n \nday-trip\n \ndestination.\n \nBlue\n \nMountain,\n \nPrince\n \nEdward\n \nCounty,\n \nand\n \nthe\n \nToronto\n \nZoo\n \nfurther\n \nenrich\n \nthe\n \nregion’s\n \ntourism\n \nofferings,\n \nproviding\n \noptions\n \nfor\n \nnature\n \nlovers,\n \nadventure\n \nseekers,\n \nfamilies,\n \nand\n \nwine\n \nenthusiasts.\n \nWhether\n \nexploring\n \nhistoric\n \ndistricts,\n \nenjoying\n \nwaterfront\n \nviews,\n \ndiving\n \ninto\n \narts\n \nand\n \nculture,\n \nor\n \nventuring\n \nout\n \non\n \nscenic\n \nday\n \ntrips,\n \nToronto\n \noffers\n \nan\n \nimpressive\n \nblend\n \nof\n \nurban\n \nsophistication,\n \ncultural\n \ndepth,\n \nand\n \nnatural\n \nbeauty—making\n \nit\n \none\n \nof\n \nthe\n \nmost\n \ncompelling\n \nand\n \nmemorable\n \ndestinations\n \nfor\n \ntravelers\n \nvisiting\n \nCanada.\n \nToronto’s  appeal  also  lies  in  how  seamlessly  it  blends  modern  urban  living  with  accessible  \nnatural\n \nretreats.\n \nVisitors\n \noften\n \nappreciate\n \nthat\n \nwithin\n \nminutes\n \nof\n \nleaving\n \nthe\n \nbusy\n \ndowntown\n \ncore,\n \nthey\n \ncan\n \nfind\n \nquiet\n \nwaterfront\n \ntrails,\n \nsprawling\n \nparks,\n \nbotanical\n \ngardens,\n \nand\n \npeaceful\n \ngreen\n \nspaces\n \nscattered\n \nthroughout\n \nthe\n \ncity.\n \nNeighborhoods\n \nsuch\n \nas\n \nthe\n \nHarbourfront\n \nand\n \nQueens\n \nQuay\n \noffer\n \nbeautiful\n \nlakeside\n \npromenades,\n \ncycling\n \npaths,\n \nand\n \nsunset\n \nviewpoints,\n \nmaking\n \nthem\n \nideal\n \nfor\n \nrelaxing\n \nwalks\n \nalong\n \nLake\n \nOntario.\n \nThe\n \ncity’s\n \nextensive\n \nnetwork\n \nof\n \nparks—including\n \nTrinity\n \nBellwoods,\n \nRiverdale\n \nPark,\n \nand\n \nRouge\n \nNational\n \nUrban\n \nPark\n \n(one\n \nof\n \nthe\n \nlargest\n \nurban\n \nparks\n \nin\n \nNorth\n \nAmerica)—provides\n \ncountless\n \nopportunit ...
#  Document(metadata={'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Travel Assistant Book', 'source': 'data/Travel Assistant Book.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='shopping  malls  like  Eaton  Centre  and  Yorkdale,  visitors  find  a  wide  range  of  options  catering  to  \nevery\n \nstyle\n \nand\n \nbudget.\n \nFood\n \nmarkets,\n \nincluding\n \nSt.\n \nLawrence\n \nMarket\n \nand\n \nKensington\n \nMarket,\n \nallow\n \ntravelers\n \nto\n \nexplore\n \nlocal\n \ningredients,\n \ninternational\n \nflavors,\n \nand\n \nunique\n \nculinary\n \ncreations\n \nfrom\n \nToronto’s\n \nmulticultural\n \ncommunities.\n \nToronto’s  accessibility  is  another  reason  it  remains  a  top  travel  destination.  The  city’s  public  \ntransit\n \nsystem—serving\n \nsubways,\n \nbuses,\n \nand\n \nstreetcars—makes\n \nit\n \neasy\n \nfor\n \nvisitors\n \nto\n \nnavigate\n \nbetween\n \nattractions.\n \nRide-share\n \nservices\n \nand\n \nwalkable\n \nneighborhoods\n \nadd\n \nconvenience,\n \nwhile\n \nToronto\n \nPearson\n \nAirport,\n \none\n \nof\n \nNorth\n \nAmerica’s\n \nbusiest,\n \nconnects\n \nthe\n \ncity\n \neffortlessly\n \nto\n \ninternational\n \ndestinations.\n \nThe\n \ncity’s\n \nblend\n \nof\n \nsafety,\n \nhospitality,\n \nand\n \nmulticultural\n \natmosphere\n \nensures\n \nthat\n \ntravelers\n \nfrom\n \nall\n \nbackgrounds\n \nfeel\n \nwelcomed\n \nand\n \ncomfortable\n \nthroughout\n \ntheir\n \nstay.\n \nOverall,  Toronto  offers  an  experience  that  captures  the  essence  of  modern  Canada:  diverse,  \nlively,\n \ninclusive,\n \nand\n \nrich\n \nwith\n \nopportunities\n \nfor\n \nexploration.\n \nWhether\n \nsomeone\n \nis\n \nseeking\n \narts\n \nand\n \nentertainment,\n \nnature\n \nand\n \nphotography,\n \nshopping\n \nand\n \ndining,\n \nor\n \nsimply\n \nthe\n \nenergy\n \nof\n \na\n \nmajor\n \nglobal\n \ncity,\n \nToronto\n \nprovides\n \na\n \ndynamic\n \nand\n \nmemorable\n \ndestination\n \nthat\n \ncontinues\n \nto\n \ninspire\n \nvisitors\n \nyear\n \nafter\n \nyear.\n \nHere  is  another  smooth  and  detailed  extension ,  adding  even  more  lines  to  enrich  the  Toronto  \ndescription\n \nwith\n \nlifestyle,\n \nneighborhoods,\n \nseasonal\n \nexperiences,\n \nand\n \noverall\n \ntravel\n \nfeel—while\n \nkeeping\n \nthe\n \ntone\n \nconsistent,\n \npolished,\n \nand\n \naligned\n \nwith\n \nthe\n \nPDF’s\n \ncontent.\n \n \nToronto’s  dynamic  identity  is  also  shaped  by  the  distinct  character  of  its  neighborhoods,  each  \noffering\n \na\n \nunique\n \natmosphere\n \nand\n \nexperience\n \nfor\n \nvisitors.\n \nAreas\n \nlike\n \nYorkville\n \nshowcase\n \nluxury\n \nboutiques,\n \nupscale\n \ndining,\n \nand\n \nelegant\n \nstreets\n \nideal\n \nfor\n \nhigh-end\n \nshopping\n \nand\n \nrefined\n \nevenings\n \nout.\n \nIn\n \ncontrast,\n \nKensington\n \nMarket\n \nvibrates\n \nwith\n \nartistic\n \nenergy,\n \nmulticultural\n \nfood\n \nstalls,\n \nvintage\n \nshops,\n \nand\n \ncolorful\n \nmurals,\n \nmaking\n \nit\n \na\n \nfavorite\n \nfor\n \ncreative\n \ntravelers\n \nand\n \nfood\n \nexplorers.\n \nThe\n \nDistillery\n \nDistrict,\n \nwith\n \nits\n \npedestrian-only\n \ncobblestone\n \nstreets\n \nand\n \npreserved\n \nVictorian-era\n \nbuildings,\n \noffers\n \nhistoric\n \ncharm,\n \ncraft\n \nbreweries,\n \nboutique\n \ngalleries,\n \nand\n \nseasonal\n \nmarkets\n \nthat\n \nattract\n \nboth\n \ntourists\n \nand\n \nlocals\n \nthroughout\n \nthe\n \nyear.\n \nMeanwhile,\n \nChinatown\n \nand\n \nKoreatown\n \npresent\n \nauthentic\n \nAsian\n \ncuisine\n \nand\n \nvibrant\n \nstreet\n \nlife,\n \nallowing\n \nvisitors\n \nto\n \nimmerse\n \nthemselves\n \nin\n \nToronto’s\n \nmulticultural\n \nculinary\n \nheritage.\n \nThe  city’s  waterfront  lifestyle  adds  another  memorable  dimension  to  the  visitor  experience.  \nToronto’s\n \nlakefront\n \nis\n \nhome\n \nto\n \n ...
#  Document(metadata={'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Travel Assistant Book', 'source': 'data/Travel Assistant Book.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='Seasonal  changes  deeply  enrich  the  tourist  experience  in  Toronto.  Spring  brings  cherry  \nblossoms\n \nto\n \nHigh\n \nPark\n \nand\n \nTrinity\n \nBellwoods,\n \ndrawing\n \ncrowds\n \nof\n \nphotographers\n \nand\n \nnature\n \nlovers.\n \nSummer\n \nis\n \nfilled\n \nwith\n \noutdoor\n \nfestivals,\n \nfrom\n \nfood\n \ncelebrations\n \nto\n \ncultural\n \nparades,\n \nmusic\n \nconcerts,\n \nand\n \nnight\n \nmarkets\n \nthat\n \ntransform\n \nthe\n \ncity\n \ninto\n \na\n \nlively,\n \nopen-air\n \nplayground.\n \nAutumn\n \nbathes\n \nthe\n \ncity\n \nin\n \ngolden\n \nand\n \nred\n \nhues,\n \nwith\n \nplaces\n \nlike\n \nthe\n \nDon\n \nValley,\n \nRouge\n \nPark,\n \nand\n \nMount\n \nPleasant\n \nCemetery\n \nbecoming\n \ngorgeous\n \nphotography\n \nspots.\n \nWinter\n \nadds\n \na\n \nmagical\n \ncharm\n \nwith\n \nholiday\n \nlights,\n \nice\n \nskating\n \nat\n \nNathan\n \nPhillips\n \nSquare,\n \nChristmas\n \nmarkets\n \nin\n \nthe\n \nDistillery\n \nDistrict,\n \nand\n \ncozy\n \nindoor\n \nattractions\n \nlike\n \nmuseums\n \nand\n \ngalleries.\n \nToronto’s  balance  of  modern  sophistication  and  cultural  depth  also  makes  it  a  compelling  choice  \nfor\n \nbusiness\n \ntravelers,\n \nstudents,\n \nfamilies,\n \nand\n \nsolo\n \nadventurers\n \nalike.\n \nIts\n \nreputation\n \nfor\n \nsafety,\n \ncleanliness,\n \nand\n \nhospitality\n \nensures\n \na\n \nwelcoming\n \nenvironment\n \nfor\n \nnewcomers,\n \nwhile\n \nits\n \nefficient\n \ntransportation\n \nsystem\n \nmakes\n \nnavigating\n \nthe\n \ncity\n \neasy\n \nand\n \ncomfortable.\n \nWhether\n \nsomeone\n \narrives\n \nfor\n \nsightseeing,\n \nfood\n \ntourism,\n \nentertainment,\n \nsports\n \nevents,\n \nor\n \nnature\n \nescapes,\n \nToronto\n \nconsistently\n \ndelivers\n \na\n \nrich\n \nblend\n \nof\n \nexperiences\n \nthat\n \ncater\n \nto\n \nevery\n \ninterest\n \nand\n \ntravel\n \nstyle.\n \nWith\n \nits\n \nmulticultural\n \nspirit,\n \niconic\n \nattractions,\n \nscenic\n \nwaterfront,\n \nand\n \nvibrant\n \nyear-round\n \nactivities,\n \nToronto\n \nembodies\n \nthe\n \nvery\n \nbest\n \nof\n \nCanadian\n \nurban\n \nculture\n \nand\n \nremains\n \none\n \nof\n \nthe\n \ncountry’s\n \nmost\n \nrewarding\n \ncities\n \nto\n \nexplore.\n \nToronto’s  transportation  network  plays  a  major  role  in  making  the  city  accessible  and  enjoyable  \nfor\n \nvisitors.\n \nThe\n \nToronto\n \nTransit\n \nCommission\n \n(TTC)\n \noperates\n \nan\n \nextensive\n \nsystem\n \nof\n \nsubways,\n \nstreetcars,\n \nand\n \nbuses\n \nthat\n \nconnect\n \nalmost\n \nevery\n \ncorner\n \nof\n \nthe\n \ncity.\n \nThe\n \nsubway\n \noffers\n \nthe\n \nfastest\n \nway\n \nto\n \nmove\n \nthrough\n \ndowntown\n \nand\n \nacross\n \nmajor\n \ndistricts,\n \nwhile\n \nthe\n \niconic\n \nstreetcars\n \nprovide\n \nscenic\n \nrides\n \nthrough\n \nbusy\n \nneighborhoods\n \nand\n \ncultural\n \nareas.\n \nFor\n \nlonger\n \ncommutes\n \nor\n \ntravel\n \nto\n \nsurrounding\n \ncities\n \nin\n \nthe\n \nGreater\n \nToronto\n \nArea,\n \nGO\n \nTransit’s\n \ntrains\n \nand\n \nbuses\n \noffer\n \nefficient\n \nregional\n \nconnections\n \nto\n \nplaces\n \nlike\n \nMississauga,\n \nBrampton,\n \nOakville,\n \nHamilton,\n \nand\n \nOshawa.\n \nTravelers\n \ncan\n \nalso\n \nrely\n \non\n \nthe\n \nUP\n \nExpress,\n \na\n \nrapid\n \ntrain\n \nlinking\n \ndowntown\n \nToronto\n \nto\n \nPearson\n \nInternational\n \nAirport\n \nin\n \njust\n \n25\n \nminutes,\n \nmaking\n \nairport\n \ntransfers\n \nconvenient\n \nand\n \nstress-free.\n \nRide-sharing\n \nservices\n \nsuch\n \nas\n \nUber\n \nand\n \nLyft\n \nare\n \nwidely\n \navailable,\n \nand\n \nToronto’s\n \nwalkable\n \ndowntown,\n \nbik ...
#  Document(metadata={'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Travel Assistant Book', 'source': 'data/Travel Assistant Book.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='dishes,  indulging  in  global  flavors,  or  exploring  trendy  fusion  restaurants,  visitors  quickly  \ndiscover\n \nwhy\n \nToronto\n \nis\n \nconsidered\n \none\n \nof\n \nthe\n \nworld’s\n \nmost\n \nexciting\n \nculinary\n \ndestinations.\n \nThe  combination  of  efficient  transportation  and  an  outstanding  food  culture  significantly  \nenhances\n \nthe\n \noverall\n \ntravel\n \nexperience\n \nin\n \nToronto.\n \nWith\n \nthe\n \nease\n \nof\n \ngetting\n \naround\n \nthe\n \ncity\n \nand\n \nthe\n \nendless\n \nvariety\n \nof\n \ndining\n \noptions,\n \ntourists\n \ncan\n \neffortlessly\n \nexplore\n \nmultiple\n \ndistricts\n \nin\n \na\n \nsingle\n \nday—enjoying\n \nmuseums\n \nin\n \nthe\n \nmorning,\n \neating\n \nstreet\n \nfood\n \nfor\n \nlunch,\n \nvisiting\n \nwaterfront\n \nparks\n \nin\n \nthe\n \nafternoon,\n \nand\n \nending\n \nthe\n \nevening\n \nwith\n \nfine\n \ndining\n \nor\n \nvibrant\n \nnightlife.\n \nThis\n \nseamless\n \nblend\n \nof\n \naccessibility,\n \nculture,\n \nand\n \ncuisine\n \nensures\n \nthat\n \nevery\n \ntrip\n \nto\n \nToronto\n \nis\n \nrich,\n \nmemorable,\n \nand\n \nfilled\n \nwith\n \nimmersive\n \nexperiences\n \nthat\n \nhighlight\n \nthe\n \ncity’s\n \nmulticultural\n \nheart\n \nand\n \nglobal\n \ncharm.\n \nToronto  also  offers  an  exceptional  shopping  experience  that  appeals  to  every  type  of  traveler.  \nVisitors\n \nwho\n \nenjoy\n \nluxury\n \nbrands\n \nand\n \ndesigner\n \nfashion\n \ncan\n \nexplore\n \nYorkville,\n \nan\n \nupscale\n \nneighborhood\n \nfilled\n \nwith\n \nhigh-end\n \nboutiques,\n \nelegant\n \ncafés,\n \nand\n \npremium\n \ninternational\n \nlabels.\n \nFor\n \na\n \nmore\n \nmainstream\n \nbut\n \nequally\n \nexciting\n \nshopping\n \nenvironment,\n \nthe\n \nEaton\n \nCentre—one\n \nof\n \nCanada’s\n \nbusiest\n \nmalls—provides\n \nhundreds\n \nof\n \nstores\n \nunder\n \na\n \nspectacular\n \nglass\n \ngalleria\n \nin\n \nthe\n \nheart\n \nof\n \ndowntown.\n \nYorkdale\n \nMall,\n \nknown\n \nfor\n \nits\n \npremium\n \nretailers\n \nand\n \nmodern\n \ndesign,\n \nis\n \nanother\n \npopular\n \ndestination\n \nfor\n \nfashion\n \nenthusiasts.\n \nTravelers\n \nwho\n \nprefer\n \nunique,\n \nartistic,\n \nor\n \nvintage\n \nitems\n \noften\n \ngravitate\n \ntoward\n \nQueen\n \nStreet\n \nWest\n \nand\n \nKensington\n \nMarket,\n \nwhere\n \nindependent\n \ndesigners,\n \nthrift\n \nshops,\n \nstreet\n \nart,\n \nand\n \nhandmade\n \ncrafts\n \ncreate\n \na\n \none-of-a-kind\n \nretail\n \natmosphere.\n \nTogether,\n \nthese\n \ndistricts\n \nensure\n \nthat\n \nToronto\n \ncaters\n \nto\n \nevery\n \nshopping\n \npreference,\n \nfrom\n \nluxurious\n \nto\n \nhip,\n \nmodern\n \nto\n \nvintage,\n \nand\n \neverything\n \nin\n \nbetween.\n \nIn  terms  of  safety,  Toronto  is  widely  recognized  as  one  of  the  safest  major  cities  in  North  \nAmerica,\n \nmaking\n \nit\n \ncomfortable\n \nfor\n \ntourists\n \nto\n \nexplore\n \nboth\n \nday\n \nand\n \nnight.\n \nDowntown\n \nareas\n \nare\n \nwell-lit,\n \npublic\n \ntransit\n \nis\n \nreliable,\n \nand\n \ncrime\n \nrates\n \nremain\n \nlow\n \ncompared\n \nto\n \nother\n \ncities\n \nof\n \nsimilar\n \nsize.\n \nWhile\n \npetty\n \ntheft\n \ncan\n \noccur\n \nin\n \ncrowded\n \nspaces—as\n \nin\n \nany\n \nurban\n \ndestination—travelers\n \ngenerally\n \nfeel\n \nsecure\n \nwalking\n \nthrough\n \ntourist\n \nareas,\n \nwaterfront\n \nhubs,\n \nand\n \nmajor\n \nneighborhoods.\n \nThe\n \ncity’s\n \nemergency\n \nservices\n \nare\n \nhighly\n \nefficient,\n \nand\n \n911\n \nis\n \nthe\n \nprimary\n \nemergency\n \nnumber\n \nused\n \nacross\n \nCanada.\n \nMost\n \nareas\n \nare\n \nsafe\n \nfor\n \nvisitors,\n \n ...
#  Document(metadata={'producer': 'Skia/PDF m144 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Travel Assistant Book', 'source': 'data/Travel Assistant Book.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='dining,  accommodation,  and  transportation.  Budget  travelers  can  enjoy  affordable  meals  from  \nstreet\n \nvendors\n \nand\n \nethnic\n \nneighborhoods,\n \nstay\n \nin\n \nhostels\n \nor\n \nsuburban\n \nAirbnbs,\n \nand\n \nrely\n \non\n \nthe\n \nTTC\n \nfor\n \ntransportation.\n \nMid-range\n \nvisitors\n \nwill\n \nfind\n \ncomfortable\n \nhotels,\n \ndiverse\n \ndining\n \noptions,\n \nand\n \nreasonably\n \npriced\n \nattractions.\n \nThose\n \nseeking\n \nluxury\n \nhave\n \nno\n \nshortage\n \nof\n \npremium\n \nhotels,\n \nupscale\n \nrestaurants,\n \ndesigner\n \nshopping,\n \nand\n \nexclusive\n \nexperiences.\n \nWhether\n \nsomeone\n \ntravels\n \non\n \na\n \nstrict\n \nbudget\n \nor\n \nprefers\n \nhigh-end\n \ncomfort,\n \nToronto\n \nprovides\n \nexcellent\n \nvalue\n \nfor\n \nits\n \nlevel\n \nof\n \nquality\n \nand\n \nvariety.\n \nAltogether,  these  elements—transportation,  food,  shopping,  safety,  etiquette,  and  \nbudget—combine\n \nto\n \nmake\n \nToronto\n \none\n \nof\n \nthe\n \nmost\n \ncomplete\n \nand\n \nenjoyable\n \ntravel\n \ndestinations\n \nin\n \nCanada.\n \nThe\n \ncity’s\n \nunique\n \nblend\n \nof\n \nmetropolitan\n \nexcitement,\n \nmulticultural\n \nrichness,\n \nscenic\n \nwaterfronts,\n \nworld-class\n \nattractions,\n \nand\n \nwarm\n \nhospitality\n \nensures\n \nthat\n \nevery\n \nvisitor,\n \nwhether\n \narriving\n \nfor\n \nthe\n \nfirst\n \ntime\n \nor\n \nreturning\n \nonce\n \nagain,\n \nfinds\n \nsomething\n \nnew\n \nand\n \nmemorable\n \nto\n \nexperience.\n \nWith\n \nso\n \nmuch\n \nto\n \noffer\n \nacross\n \nevery\n \nseason,\n \nToronto\n \nstands\n \nas\n \na\n \nvibrant,\n \ninclusive,\n \nand\n \nendlessly\n \nengaging\n \ncity\n \nthat\n \nreflects\n \nthe\n \nvery\n \nbest\n \nof\n \nCanadian\n \nculture\n \nand\n \nurban\n \nlife.')]

# %%
from typing import List
from langchain.schema import Document

def filter_to_minimal_docs(docs:List[Document]) -> List[Document]:
    """
    Given a list of Document objects, return a new list of Document objects 
    containing only 'source' in metadata and the page_content.
    """


    minimal_docs: List[Document] = []

    for doc in docs:
        src = doc.metadata.get("source")
        minimal_docs.append(Document(
                                     page_content = doc.page_content,
                                     metadata={"source":src}))
        
        return minimal_docs

# %%
minimal_docs = filter_to_minimal_docs(extracted_data)
minimal_docs
# Out:
# [Document(metadata={'source': 'data/Travel Assistant Book.pdf'}, page_content='Toronto  —  Detailed  Overview  With  Tourist  Attractions   Toronto  is  the  largest  and  most  influential  city  in  Canada,  positioned  along  the  northwestern  \nshore\n \nof\n \nLake\n \nOntario\n \nand\n \nrecognized\n \nas\n \nthe\n \nnation’s\n \ncultural,\n \nfinancial,\n \nand\n \nentertainment\n \ncapital.\n \nCelebrated\n \nas\n \none\n \nof\n \nthe\n \nmost\n \nmulticultural\n \ncities\n \nin\n \nthe\n \nworld,\n \nToronto\n \nis\n \nhome\n \nto\n \nover\n \n200\n \nethnic\n \ncommunities,\n \ncreating\n \nan\n \nincredibly\n \ndiverse\n \natmosphere\n \nreflected\n \nin\n \nits\n \nneighborhoods,\n \nfood\n \nscene,\n \nfestivals,\n \nand\n \neveryday\n \nlife.\n \nThe\n \ncity’s\n \nmodern\n \nskyline—dominated\n \nby\n \nthe\n \niconic\n \n553-meter\n \nCN\n \nTower—sits\n \nabove\n \na\n \nbustling\n \nurban\n \ncore\n \nfilled\n \nwith\n \ntheatres,\n \nmuseums,\n \nshopping\n \ndistricts,\n \nand\n \nwaterfront\n \nattractions.\n \nToronto\n \nforms\n \nthe\n \nheart\n \nof\n \nthe\n \nGreater\n \nToronto\n \nArea\n \n(GTA),\n \nwhich\n \nincludes\n \nsurrounding\n \ncities\n \nsuch\n \nas\n \nMississauga,\n \nBrampton,\n \nMarkham,\n \nVaughan,\n \nRichmond\n \nHill,\n \nand\n \nPickering,\n \nmaking\n \nit\n \none\n \nof\n \nNorth\n \nAmerica’s\n \nlargest\n \nmetropolitan\n \nregions.\n \nThe\n \ngeography\n \nrevolves\n \naround\n \nToronto\n \nHarbour\n \nand\n \nan\n \nextensive\n \nwaterfront,\n \nwith\n \nvibrant\n \ndistricts\n \nbranching\n \noutward\n \ninto\n \nmulticultural\n \npockets\n \nand\n \nsuburban\n \ncommunities.\n \nToronto’s  continental  climate,  influenced  by  Lake  Ontario,  brings  cold  but  manageable  winters  \nranging\n \nfrom\n \n−5°C\n \nto\n \n−15°C,\n \nwarm\n \nand\n \nactive\n \nsummers\n \nbetween\n \n22°C\n \nand\n \n30°C,\n \nand\n \nmild\n \nbut\n \nwindy\n \nconditions\n \nin\n \nspring\n \nand\n \nfall—each\n \nseason\n \nshaping\n \nthe\n \ncity’s\n \ntourism\n \npatterns.\n \nThe\n \ncity\n \nattracts\n \nmillions\n \nof\n \nvisitors\n \nannually\n \nfor\n \nits\n \nblend\n \nof\n \nnatural\n \nbeauty,\n \ncultural\n \nrichness,\n \nand\n \nworld-class\n \nattractions.\n \nThe\n \nCN\n \nTower\n \nremains\n \nthe\n \nmost\n \nfamous\n \nlandmark,\n \noffering\n \nglass-floor\n \nviews,\n \na\n \nrevolving\n \nrestaurant,\n \nand\n \nthe\n \nthrilling\n \noutdoor\n \nEdgeWalk\n \nexperience.\n \nNature\n \nlovers\n \nenjoy\n \nthe\n \nToronto\n \nIslands,\n \nreached\n \nby\n \na\n \nshort\n \nferry\n \nride,\n \nwhere\n \nbeaches,\n \nbike\n \npaths,\n \npicnic\n \nspots,\n \nand\n \nskyline\n \nviews\n \ncreate\n \na\n \npeaceful\n \nescape\n \nfrom\n \ndowntown.\n \nHigh\n \nPark\n \nis\n \nanother\n \nmajor\n \noutdoor\n \nspace,\n \nwell-known\n \nfor\n \ncherry\n \nblossoms\n \nin\n \nspring,\n \nextensive\n \ntrails,\n \nand\n \nfamily-friendly\n \nactivities.\n \nFor\n \ndramatic\n \nlakefront\n \nscenery,\n \nthe\n \nScarborough\n \nBluffs\n \nprovide\n \ntowering\n \ncliffs,\n \npanoramic\n \nviews,\n \nand\n \npicturesque\n \nbeaches.\n \nCulturally,  Toronto  offers  exceptional  institutions  such  as  the  Royal  Ontario  Museum—Canada’s  \nlargest\n \nmuseum\n \nfeaturing\n \nglobal\n \nhistory,\n \ndinosaurs,\n \nand\n \nIndigenous\n \ncollections—and\n \nthe\n \nArt\n \nGallery\n \nof\n \nOntario,\n \nwhich\n \nhouses\n \nmore\n \nthan\n \n95,000\n \nworks\n \nand\n \noffers\n \nfree\n \nadmission\n \non\n \nWednesday\n \nevenings.\n \nShopping\n \ndistricts\n \nlike\n \nthe\n \nEaton\n \nCentre,\n \nYorkdale\n \nMall,\n \nQueen\n \nStreet\n \nWest,\n \nand\n \nKensington\n \nMarket\n \noffer\n \neverything\n \nfrom\n \nluxury\n \nbrands\n \nto\n \nvintage\n \nfinds\n \nand\n \nartisanal\n \ngoods.\n \nDistinct\n \nneighborhoods\n \nsuch\n \nas\n \nthe\n \nDistillery\n \nDistrict,\n \nKensington\n \nMarket,\n \nChinatown,\n \nKoreatown,\n \nYorkville,\n \nand\n ...

# %% [markdown]
# ####Chunking

# %%
# Split the documents into smaller chunks
def text_split(minimal_docs):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = 500,
        chunk_overlap = 10,
    )

    texts_chunk = text_splitter.split_documents(minimal_docs)
    return texts_chunk

# %%
texts_chunk = text_split(minimal_docs)
print(f"Number of chunks:{len(texts_chunk)}")
# Out:
# Number of chunks:9

# %% [markdown]
# ### Embedding

# %%
from langchain.embeddings import HuggingFaceEmbeddings

def download_embeddings():
    """
    Download and return the HuggingFace embeddings model.
    """
    model_name = "sentence-transformers/all-MiniLM-L6-v2"
    embeddings = HuggingFaceEmbeddings(
        model_name=model_name
    )
    return embeddings

embedding = download_embeddings()

# %%
embedding
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
vector = embedding.embed_query("Hi")
print( "Vector length:", len(vector))
# Out:
# Vector length: 384

# %%
import os
#os.environ["OPENAI_API_KEY"] =

# %% [markdown]
# ###Pinecone dB

# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")


os.environ["PINECONE_API_KEY"] = PINECONE_API_KEY
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY

# %%
from pinecone import Pinecone 
pinecone_api_key = PINECONE_API_KEY

pc = Pinecone(api_key=pinecone_api_key)

# %%
from pinecone import ServerlessSpec 

index_name = "chatbot"

if not pc.has_index(index_name):
    pc.create_index(
        name = index_name,
        dimension=384,  # Dimension of the embeddings
        metric= "cosine",  # Cosine similarity
        spec=ServerlessSpec(cloud="aws", region="us-east-1")
    )


index = pc.Index(index_name)

# %%
from langchain_pinecone import PineconeVectorStore

docsearch = PineconeVectorStore.from_documents(
    documents=texts_chunk,
    embedding=embedding,
    index_name=index_name
)

# %%
# Load Existing index 

from langchain_pinecone import PineconeVectorStore
# Embed each chunk and upsert the embeddings into your Pinecone index.
docsearch = PineconeVectorStore.from_existing_index(
    index_name=index_name,
    embedding=embedding
)

# %%
## Add more data to existing pinecone index

docs_extra = Document(
    page_content= "Tourist Attraction: Niagara Falls (Ontario), Niagara Falls is one of Canada’s most iconic natural attractions, located on the border between Ontario, Canada, and New York, USA. Famous for its breathtaking beauty and massive water flow, the falls consist of three main sections: Horseshoe Falls (the largest and most impressive), American Falls, and Bridal Veil Falls. Visitors can experience the falls from multiple viewpoints along the Niagara Parkway, but the most immersive experience is through the Hornblower Boat Cruise, where boats take passengers close enough to feel the mist. The area surrounding the falls offers attractions including Journey Behind the Falls, Skylon Tower observation deck, and Clifton Hill, a lively entertainment district filled with restaurants, museums, arcades, and attractions. Niagara Falls is accessible from Toronto in about 1.5 hours by car or GO Train, making it one of the most convenient and popular day trips for tourists visiting Canada.",
    metadata ={"source":"Website"}
)

# %%
docsearch.add_documents(documents=[docs_extra])
# Out:
# ['f8dcced8-600e-4841-a217-c86ffda99351']

# %%
retriever = docsearch.as_retriever(search_type="similarity", search_kwargs={"k":3})

# %%
retrieved_docs = retriever.invoke("What are the best places to visit in Toronto??")
retrieved_docs
# Out:
# [Document(id='2ed0beaa-7a43-4a34-9339-04b0e8ebf07b', metadata={'source': 'data/Travel Assistant Book.pdf'}, page_content='its\n \nwalkable\n \ndowntown,\n \nwaterfront\n \npromenades,\n \nand\n \ninterconnected\n \nneighborhoods\n \nmake\n \nexploration\n \neasy\n \nand\n \nenjoyable.\n \nOverall,\n \nToronto\n \nstands\n \nout\n \nas\n \na\n \nvibrant,\n \ninclusive,\n \nand\n \nculturally\n \ndynamic\n \nmetropolis\n \nwhere\n \nglobal'),
#  Document(id='8ac543f5-b1b3-4372-94f8-1e41e52503d0', metadata={'source': 'data/Travel Assistant Book.pdf'}, page_content='Toronto  —  Detailed  Overview  With  Tourist  Attractions   Toronto  is  the  largest  and  most  influential  city  in  Canada,  positioned  along  the  northwestern  \nshore\n \nof\n \nLake\n \nOntario\n \nand\n \nrecognized\n \nas\n \nthe\n \nnation’s\n \ncultural,\n \nfinancial,\n \nand\n \nentertainment\n \ncapital.\n \nCelebrated\n \nas\n \none\n \nof\n \nthe\n \nmost\n \nmulticultural\n \ncities\n \nin\n \nthe\n \nworld,\n \nToronto\n \nis\n \nhome\n \nto\n \nover\n \n200\n \nethnic\n \ncommunities,\n \ncreating\n \nan\n \nincredibly\n \ndiverse\n \natmosphere'),
#  Document(id='da7ff057-ecc1-439c-9ec0-c4574d839c50', metadata={'source': 'data/Travel Assistant Book.pdf'}, page_content='scene\n \nis\n \nequally\n \nstrong,\n \nwith\n \nthe\n \nScotiabank\n \nArena\n \nhosting\n \nthe\n \nToronto\n \nRaptors\n \n(NBA)\n \nand\n \nToronto\n \nMaple\n \nLeafs\n \n(NHL),\n \nthe\n \nRogers\n \nCentre\n \nhome\n \nto\n \nthe\n \nBlue\n \nJays\n \n(MLB),\n \nand\n \na\n \nthriving\n \ntheatre\n \ndistrict\n \nfeaturing\n \nBroadway-style\n \nshows\n \nand\n \nmusicals.\n \nToronto’s  safety,  cleanliness,  and  reliable  public  transportation—made  up  of  subways,  buses,  \nand\n \nstreetcars—enhance\n \nits\n \nappeal\n \nfor\n \nvisitors,\n \nwhile\n \nits')]

# %%
from langchain_openai import ChatOpenAI

chatModel = ChatOpenAI(model="gpt-4o-mini", api_key=os.environ["OPENAI_API_KEY"])

# %%
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# %%
system_prompt = (
    "You are a Travel Information Assistant that answers questions about Canada and its major cities "
    "(Toronto, Vancouver, Montreal, Calgary, and Ottawa). "
    "Use the retrieved context provided to answer the user's question accurately. "
    "If the answer is not in the context, respond with 'I don't know based on the provided information.' "
    "Keep the answer concise, clear, and limited to a maximum of three sentences. "
    "Do not add information that is not supported by the context. "
    "\n\n"
    "{context}"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}"),
    ]
)

# %%
question_answer_chain = create_stuff_documents_chain(chatModel, prompt)
rag_chain = create_retrieval_chain(retriever, question_answer_chain)

# %%
response = rag_chain.invoke({"input": "What are the main attractions in Toronto?"})
print(response["answer"])
# Out:
# I don't know based on the provided information.

# %%
from langchain_openai import ChatOpenAI
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain.chains import create_retrieval_chain
from langchain_core.prompts import ChatPromptTemplate
import os

# ---------------------------------------------------------
# 3) INITIALIZE OPENAI MODEL
# ---------------------------------------------------------
llm = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    temperature=0.0
)

# ---------------------------------------------------------
# 4) SYSTEM PROMPT FOR RAG
# ---------------------------------------------------------
system_prompt = (
    "You are a Travel Information Assistant that answers questions about Canada "
    "and its major cities (Toronto, Vancouver, Montreal, Calgary, and Ottawa). "
    "Use ONLY the retrieved context to answer. "
    "If the context does not contain the answer, say: 'I don't know based on the provided information.'\n\n"
    "CONTEXT:\n{context}"
)

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", system_prompt),
        ("human", "{input}")
    ]
)

# ---------------------------------------------------------
# 5) RAG PIPELINE
# ---------------------------------------------------------
# retriever MUST already be defined earlier in your notebook
# example: retriever = vectorstore.as_retriever()

qa_chain = create_stuff_documents_chain(
    llm=llm,
    prompt=prompt
)

rag_chain = create_retrieval_chain(
    retriever=retriever,
    combine_docs_chain=qa_chain
)

# ---------------------------------------------------------
# 6) TEST THE RAG PIPELINE
# ---------------------------------------------------------
query = "Tell me about Niagara Falls"
response = rag_chain.invoke({"input": query})

# %%
query_result = response["answer"]
print(query_result)
# Out:
# Niagara Falls is one of Canada’s most iconic natural attractions, located on the border between Ontario, Canada, and New York, USA. It is famous for its breathtaking beauty and massive water flow, consisting of three main sections: Horseshoe Falls (the largest and most impressive), American Falls, and Bridal Veil Falls. Visitors can experience the falls from multiple viewpoints along the Niagara Parkway, but the most immersive experience is through the Hornblower Boat Cruise, where boats take passengers close enough to feel the mist. The area surrounding the falls offers attractions including Journey Behind the Falls, Skylon Tower observation deck, and Clifton Hill, a lively entertainment district filled with restaurants, museums, arcades, and attractions. Niagara Falls is accessible from Toronto in about 1.5 hours by car or GO Train, making it one of the most convenient and popular day trips for tourists visiting Canada.

# %%
query = "Tell me about tourist attractions in Toronto?"
response = rag_chain.invoke({"input": query})
query_result = response["answer"]
print(query_result)
# Out:
# Toronto offers a variety of tourist attractions, including:
#
# 1. **Royal Ontario Museum** - Canada’s largest museum featuring global history, dinosaurs, and Indigenous collections.
# 2. **Art Gallery of Ontario** - Houses more than 95,000 works and offers free admission on Wednesday evenings.
# 3. **Niagara Falls** - Located about 1.5 hours from Toronto, it is one of Canada’s most iconic natural attractions, known for its breathtaking beauty and massive water flow. Visitors can experience the falls through viewpoints along the Niagara Parkway or take the Hornblower Boat Cruise for an immersive experience.
#
# Additionally, Toronto is known for its shopping districts, such as the Eaton Centre, and its multicultural atmosphere, being home to over 200 ethnic communities.

# %%
query = "Tell me about transportation in toronto?"
response = rag_chain.invoke({"input": query})
query_result = response["answer"]
print(query_result)
# Out:
# Toronto has reliable public transportation made up of subways, buses, and streetcars. The city's safety, cleanliness, and transportation options enhance its appeal for visitors. Additionally, Toronto features a walkable downtown, waterfront promenades, and interconnected neighborhoods, making exploration easy and enjoyable.
